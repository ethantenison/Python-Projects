# %%
import pandas as pd

# %%
df = pd.read_pickle('df_core_article_full_info_sample.pkl')

# %%
df_test = df.sample(500)

# %%
df_test1 = df_test.iloc[0,:]

# %%
df_test1
# Out:
# affiliation      [{'affiliation-city': 'Winter Park', '@id': '6...
# authkeywords     {'author-keyword': [{'@_fa': 'true', '$': 'Sel...
# authors          {'author': [{'ce:given-name': 'Jasmine', 'pref...
# coredata         {'srctype': 'j', 'eid': '2-s2.0-85047662403', ...
# idxterms                                                      None
# item             {'ait:process-info': {'ait:status': {'@state':...
# language                                      {'@xml:lang': 'eng'}
# subject-areas    {'subject-area': [{'@_fa': 'true', '$': 'Econo...
# Name: 2899, dtype: object

# %%
df.head(10)
# Out:
#                                           affiliation  \
# 1   {'affiliation-city': 'Santiago', '@id': '60029...
# 3   [{'affiliation-city': 'Paris', '@id': '1056157...
# 5                                                 NaN
# 6   {'affiliation-city': 'Hull', '@id': '60030469'...
# 9   {'affiliation-city': 'Saskatoon', '@id': '6001...
# 10  [{'affiliation-city': 'Louvain-la-Neuve', '@id...
# 11  {'affiliation-city': 'Bordeaux', '@id': '60102...
# 13  [{'affiliation-city': 'Melbourne', '@id': '600...
# 14  {'affiliation-city': 'Sydney', '@id': '6002833...
# 15  {'affiliation-city': None, '@id': '109784268',...
#
#                                          authkeywords  \
# 1                                                None
# 3                                                None
# 5                                                None
# 6   {'author-keyword': [{'@_fa': 'true', '$': 'Eco...
# 9   {'author-keyword': [{'@_fa': 'true', '$': 'Non...
# ...
